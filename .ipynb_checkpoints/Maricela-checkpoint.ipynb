# %%
import gzip
from collections import defaultdict
from sklearn import linear_model
import csv
import heapq
import string
from nltk.corpus import stopwords

# %%
def readGz(path):
    for l in gzip.open(path, 'rt'):
        yield eval(l)

# %%
def parseData(fname):
    for l in gzip.open(fname):
        d = eval(l)
        yield d

# %%
data = list(parseData("CA_5.json.gz"))

# %%
places = list(parseData('places_CA.json.gz'))

# %%
reviews = list(parseData('reviews_CA.json.gz'))

# %%
data[0]
# Out:
# [{'rating': 4.0,
#   'reviewerName': 'Mary Gainza',
#   'reviewText': 'Gap always has a jean that fits awesomely, i wish their prices were a bit competitive in comparison to their outlets, also the amount of the pieces they have in store sometimes fly so quick that is hard to find an specific size with their best sellers, but in general i really like this store and most of their products.',
#   'categories': ['Clothing Store',
#    "Women's Clothing Store",
#    "Children's Clothing Store"],
#   'gPlusPlaceId': '100556368174926958612',
#   'unixReviewTime': 1355436757,
#   'reviewTime': 'Dec 13, 2012',
#   'gPlusUserId': '100000715097692381911'},
#  {'rating': 4.0,
#   'reviewerName': 'Mary Gainza',
#   'reviewText': 'Madewell girls are always nice and smiley, i really love the clothing at the madewell store, specially when they have sales item they are super nice, their dresses and also the little details they have for little gifts, like necklaces and rings.',
#   'categories': ["Women's Clothing Store"],
#   'gPlusPlaceId': '101139208042040218757',
#   'unixReviewTime': 1355436930,
#   'reviewTime': 'Dec 13, 2012',
#   'gPlusUserId': '100000715097692381911'},
#  {'rating': 4.0,
#   'reviewerName': 'Mary Gainza',
#   'reviewText': "I like the wide range macy's has in their store, however their service is not quite as good, maybe cause the store is so big, also i wish they were more attentive to the dresser area. In general they usually have good prices for dresses and i like the little starbucks inside the store.",
#   'categories': ['Department Store', "Men's Clothing Store"],
#   'gPlusPlaceId': '103732895939896117386',
#   'unixReviewTime': 1355437030,
#   'reviewTime': 'Dec 13, 2012',
#   'gPlusUserId': '100000715097692381911'},
#  {'rating': 5.0,
#   'reviewerName': 'Mary Gainza',
#   'reviewText': 'I love the guys that work at this store, they are always very friendly, smiley and happy to serve, they are also very quick with their tasks. Besides that the juices and snacks they have are really good',
#   'categories': ['Juice Shop'],
#   'gPlusPlaceId': '105777991601449500815',
#   'unixReviewTime': 1355436832,
#   'reviewTime': 'Dec 13, 2012',
#   'gPlusUserId': '100000715097692381911'},
#  {'rating': 5.0,
#   'reviewerName': 'Mary Gainza',
#   'reviewText': "I love Specialty's they have the best semi-sweet chocolate chip cookie in the world (at thats saying a lot) there's been only once out of i can't remember how many cookies i have there, that i felt the cookie was a bit too crunchy but besides that i love it, their soups are also amazing.",
#   'categories': ['Cafe'],
#   'gPlusPlaceId': '109907393708736192804',
#   'unixReviewTime': 1355436582,
#   'reviewTime': 'Dec 13, 2012',
#   'gPlusUserId': '100000715097692381911'},
#  {'rating': 4.0,
#   'reviewerName': 'Mary Gainza',
#   'reviewText': "I like browsing at nordstrom, but today while looking for a product at their chanel stand i felt the staff they had there wasn't as good, he didn't recommend me anything else or help me much with my selection of the lipstick i was looking for, their products are amazing yes, but i wish they were more helpful.",
#   'categories': ['Clothing Store'],
#   'gPlusPlaceId': '113406287918688024660',
#   'unixReviewTime': 1355436447,
#   'reviewTime': 'Dec 13, 2012',
#   'gPlusUserId': '100000715097692381911'},
#  {'rating': 4.0,
#   'reviewerName': 'Mary Gainza',
#   'reviewText': 'I like the boulange pretty much at any of their locations, however this one always kills me a bit with their closed add because i feel is a bit -tough- on the clients, besides that they are pretty nice and friendly all day and their food is yummy',
#   'categories': ['Restaurant', 'Bakery', 'Cafe'],
#   'gPlusPlaceId': '114207018058987661847',
#   'unixReviewTime': 1355436317,
#   'reviewTime': 'Dec 13, 2012',
#   'gPlusUserId': '100000715097692381911'},
#  {'rating': 5.0,
#   'reviewerName': 'Mary Gainza',
#   'reviewText': 'Sephora is a great store, i always think of back home and tell myself i wish we had sephora in my country, their staff is always helpful and smiley, their products are wide in range and they always have something nice for just anybody.  I wish their perfume selection was wider but i think the store is very complete in general.',
#   'categories': ['Cosmetics Store'],
#   'gPlusPlaceId': '114964822538426146633',
#   'unixReviewTime': 1355436651,
#   'reviewTime': 'Dec 13, 2012',
#   'gPlusUserId': '100000715097692381911'},
#  {'rating': 4.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': 'Typical Korean restaurant. Free appetizers and good "stew/soup".',
#   'categories': ['Korean Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '101859461425306200350',
#   'unixReviewTime': 1345082722,
#   'reviewTime': 'Aug 15, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 4.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': None,
#   'categories': ['Hamburger Restaurant', 'Fast Food Restaurant'],
#   'gPlusPlaceId': '105016322722009031154',
#   'unixReviewTime': 1349117838,
#   'reviewTime': 'Oct 1, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 5.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': None,
#   'categories': ['Spanish Restaurant', 'European Restaurant', 'Wine Bar'],
#   'gPlusPlaceId': '107935315651361385613',
#   'unixReviewTime': 1358481995,
#   'reviewTime': 'Jan 17, 2013',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 4.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': "This place is always busy (you know why). Very good, healthy food, strong coffee (THANK YOU!), fresh ingredients. The bad side? A little expensive and cash only. But I don't care :-)",
#   'categories': ['Cafe', 'Coffee Shop'],
#   'gPlusPlaceId': '110261600280901761501',
#   'unixReviewTime': 1336446096,
#   'reviewTime': 'May 7, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 5.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': 'Baby back ribs and tri tip A++. Service A++. The rest just A :-)',
#   'categories': ['Barbecue Restaurant'],
#   'gPlusPlaceId': '110520954941679049745',
#   'unixReviewTime': 1368150005,
#   'reviewTime': 'May 9, 2013',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 5.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': "Stop looking. Best hamburgers in town. Probably best hamburgers in LA county (yes, it's that good ;-)",
#   'categories': ['Hamburger Restaurant',
#    'American Restaurant',
#    'Barbecue Restaurant'],
#   'gPlusPlaceId': '112319808320761067861',
#   'unixReviewTime': 1336450575,
#   'reviewTime': 'May 7, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 4.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': None,
#   'categories': ['Public Library', 'Attraction'],
#   'gPlusPlaceId': '114274795730688974506',
#   'unixReviewTime': 1348962307,
#   'reviewTime': 'Sep 29, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 4.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': 'Good clam chowder, but not the best.',
#   'categories': ['Restaurant', 'Seafood Restaurant', 'Cafe'],
#   'gPlusPlaceId': '115277932735641318797',
#   'unixReviewTime': 1365291562,
#   'reviewTime': 'Apr 6, 2013',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 3.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': None,
#   'categories': ['Polynesian Restaurant',
#    'American Restaurant',
#    'Hawaiian Restaurant'],
#   'gPlusPlaceId': '115871945880957731633',
#   'unixReviewTime': 1348967455,
#   'reviewTime': 'Sep 29, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 5.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': "All you can eat good MEAT. Used the have a wider variety, but it's still good.",
#   'categories': ['Brazilian Restaurant',
#    'Latin American Restaurant',
#    'South American Restaurant'],
#   'gPlusPlaceId': '117027804265846671257',
#   'unixReviewTime': 1345082524,
#   'reviewTime': 'Aug 15, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 4.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': "Above average prices, above average quality and above average sizes. When you ask for ribs is not just the bones, they are meaty!. To me, they are way better than Tony Roma's. Also trust me on this one: pay the $14 for the fried chicken.",
#   'categories': ['Barbecue Restaurant', 'Caterer', 'Takeout Restaurant'],
#   'gPlusPlaceId': '117257078404250200338',
#   'unixReviewTime': 1336449498,
#   'reviewTime': 'May 7, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 4.0,
#   'reviewerName': 'Walter Touceda',
#   'reviewText': 'More expensive than the average Argentine restaurants, but far better quality. Grilled meat was extremely tender and flavorful.',
#   'categories': ['Argentinian Restaurant',
#    'South American Restaurant',
#    'Bar & Grill'],
#   'gPlusPlaceId': '117911270535418157784',
#   'unixReviewTime': 1348443501,
#   'reviewTime': 'Sep 23, 2012',
#   'gPlusUserId': '100002789186899500135'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Sushi Restaurant',
#    'Asian Restaurant',
#    'Japanese Restaurant'],
#   'gPlusPlaceId': '100539657974695665920',
#   'unixReviewTime': 1302881457,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Cafe', 'Italian Restaurant'],
#   'gPlusPlaceId': '100681827139733473846',
#   'unixReviewTime': 1302881040,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Brewpub', 'American Restaurant', 'Brewery'],
#   'gPlusPlaceId': '100887731203541266259',
#   'unixReviewTime': 1302881969,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['American Restaurant', 'Fondue Restaurant', 'Steak House'],
#   'gPlusPlaceId': '100998607338583184111',
#   'unixReviewTime': 1325294864,
#   'reviewTime': 'Dec 30, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Hoagie Restaurant',
#    'Cheesesteak Restaurant',
#    'Sandwich Shop'],
#   'gPlusPlaceId': '101558916725290145882',
#   'unixReviewTime': 1302898948,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Sushi Restaurant',
#    'Asian Restaurant',
#    'Japanese Restaurant'],
#   'gPlusPlaceId': '101569325572579174871',
#   'unixReviewTime': 1302881550,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Sandwich Shop', 'Fast Food Restaurant'],
#   'gPlusPlaceId': '101902084049358138734',
#   'unixReviewTime': 1317153888,
#   'reviewTime': 'Sep 27, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['American Restaurant',
#    'Breakfast Restaurant',
#    'Family Restaurant'],
#   'gPlusPlaceId': '102812440369192328274',
#   'unixReviewTime': 1302881892,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Indian Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '103394728467953830615',
#   'unixReviewTime': 1302882728,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['American Restaurant', 'Breakfast Restaurant'],
#   'gPlusPlaceId': '103661675199788170375',
#   'unixReviewTime': 1302898131,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Bar', 'Barbecue Restaurant', 'Soul Food Restaurant'],
#   'gPlusPlaceId': '103984517065131464925',
#   'unixReviewTime': 1302882094,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Sushi Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '104599764729926803486',
#   'unixReviewTime': 1302881531,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['American Restaurant'],
#   'gPlusPlaceId': '105161497931238424543',
#   'unixReviewTime': 1325294876,
#   'reviewTime': 'Dec 30, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Seafood Restaurant'],
#   'gPlusPlaceId': '106455018675066081494',
#   'unixReviewTime': 1302898113,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Breakfast Restaurant', 'Cafe', 'Caterer'],
#   'gPlusPlaceId': '107379141439231439237',
#   'unixReviewTime': 1302898317,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': 'The Best sandwich shop at 595 Market',
#   'categories': ['Organic Restaurant', 'Sandwich Shop'],
#   'gPlusPlaceId': '107966414088597011109',
#   'unixReviewTime': 1316551474,
#   'reviewTime': 'Sep 20, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': 'Good steaks, friendly staff.',
#   'categories': ['Steak House'],
#   'gPlusPlaceId': '108746023275096721325',
#   'unixReviewTime': 1376790930,
#   'reviewTime': 'Aug 17, 2013',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Vietnamese Restaurant',
#    'Asian Restaurant',
#    'Southeast Asian Restaurant'],
#   'gPlusPlaceId': '108965565670510081634',
#   'unixReviewTime': 1305161273,
#   'reviewTime': 'May 11, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Seafood Restaurant', 'Seafood Market'],
#   'gPlusPlaceId': '109311307621925075804',
#   'unixReviewTime': 1314648799,
#   'reviewTime': 'Aug 29, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Chicken Restaurant', 'Korean Restaurant'],
#   'gPlusPlaceId': '109464886480434924863',
#   'unixReviewTime': 1305161251,
#   'reviewTime': 'May 11, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Sports Bar', 'Night Club', 'Pub'],
#   'gPlusPlaceId': '109552619713519861278',
#   'unixReviewTime': 1302819272,
#   'reviewTime': 'Apr 14, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Seafood Restaurant'],
#   'gPlusPlaceId': '109878016111199852409',
#   'unixReviewTime': 1322683879,
#   'reviewTime': 'Nov 30, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': 'Best falafel in North-East Sunnyvale',
#   'categories': ['Mediterranean Restaurant',
#    'Middle Eastern Restaurant',
#    'Salad Shop'],
#   'gPlusPlaceId': '110202037843931429970',
#   'unixReviewTime': 1314302899,
#   'reviewTime': 'Aug 25, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Restaurant', 'Breakfast Restaurant'],
#   'gPlusPlaceId': '110621095385355177847',
#   'unixReviewTime': 1302881922,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': 'The food was okay..... Nothing worth writing about. ops.',
#   'categories': ['Greek Restaurant',
#    'European Restaurant',
#    'Mediterranean Restaurant'],
#   'gPlusPlaceId': '110920299157623781358',
#   'unixReviewTime': 1317153771,
#   'reviewTime': 'Sep 27, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Mexican Restaurant', 'Latin American Restaurant'],
#   'gPlusPlaceId': '111201636234658514731',
#   'unixReviewTime': 1346366066,
#   'reviewTime': 'Aug 30, 2012',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': 'It was much better two years ago, what happened?',
#   'categories': ['Sandwich Shop', 'Fast Food Restaurant', 'Coffee Shop'],
#   'gPlusPlaceId': '111560170040558147802',
#   'unixReviewTime': 1316551419,
#   'reviewTime': 'Sep 20, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Mongolian Barbecue Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '112056440199499067697',
#   'unixReviewTime': 1302816423,
#   'reviewTime': 'Apr 14, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Japanese Restaurant', 'Sushi Restaurant'],
#   'gPlusPlaceId': '112278546760165074561',
#   'unixReviewTime': 1302881499,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Asian Restaurant',
#    'Southeast Asian Restaurant',
#    'Vietnamese Restaurant'],
#   'gPlusPlaceId': '112610750235634830337',
#   'unixReviewTime': 1302894439,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Barbecue Restaurant',
#    'Korean Restaurant',
#    'Buffet Restaurant'],
#   'gPlusPlaceId': '112744828068612948224',
#   'unixReviewTime': 1302882156,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Indian Restaurant',
#    'Asian Restaurant',
#    'South Asian Restaurant'],
#   'gPlusPlaceId': '112818240319279999644',
#   'unixReviewTime': 1302882751,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Sushi Restaurant',
#    'Asian Restaurant',
#    'Japanese Restaurant'],
#   'gPlusPlaceId': '113290396185293876210',
#   'unixReviewTime': 1302881432,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': 'I love eating breakfast in the open air patio, but the last three times I went there it was closed so I stopped going. The last time I went I was so disappointed I left to go to Stacks.',
#   'categories': ['American Restaurant',
#    'Breakfast Restaurant',
#    'Family Restaurant'],
#   'gPlusPlaceId': '114236831589464986178',
#   'unixReviewTime': 1302881877,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Japanese Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '114610039236187365572',
#   'unixReviewTime': 1302881352,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['American Restaurant', 'Barbecue Restaurant', 'Wine Bar'],
#   'gPlusPlaceId': '114735143729299990529',
#   'unixReviewTime': 1314649090,
#   'reviewTime': 'Aug 29, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Restaurant', 'Seafood Restaurant', 'Family Restaurant'],
#   'gPlusPlaceId': '115104207305151193116',
#   'unixReviewTime': 1302882028,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Seafood Restaurant'],
#   'gPlusPlaceId': '115270991893461782543',
#   'unixReviewTime': 1302898897,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Japanese Restaurant',
#    'Asian Restaurant',
#    'Seafood Restaurant'],
#   'gPlusPlaceId': '115935235307703258748',
#   'unixReviewTime': 1302881062,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Sushi Restaurant', 'Asian Restaurant', 'Seafood Restaurant'],
#   'gPlusPlaceId': '116019957721980938113',
#   'unixReviewTime': 1305235050,
#   'reviewTime': 'May 12, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Restaurant',
#    'Caribbean Restaurant',
#    'Latin American Restaurant'],
#   'gPlusPlaceId': '116714290900672170748',
#   'unixReviewTime': 1302882358,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 4.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Japanese Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '116818894403561351330',
#   'unixReviewTime': 1302881282,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 2.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': 'I eat there every week and its usually not a good experience.',
#   'categories': ['Cafe', 'Dessert Shop', 'Cookie Shop'],
#   'gPlusPlaceId': '117261877263612920264',
#   'unixReviewTime': 1314650221,
#   'reviewTime': 'Aug 29, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Restaurant', 'Breakfast Restaurant', 'American Restaurant'],
#   'gPlusPlaceId': '117346520990183666834',
#   'unixReviewTime': 1302898813,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['Sushi Restaurant',
#    'Asian Restaurant',
#    'Japanese Restaurant'],
#   'gPlusPlaceId': '117879594243299808069',
#   'unixReviewTime': 1302881517,
#   'reviewTime': 'Apr 15, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 3.0,
#   'reviewerName': 'Rick Casady',
#   'reviewText': None,
#   'categories': ['European Restaurant',
#    'Fast Food Restaurant',
#    'Italian Restaurant'],
#   'gPlusPlaceId': '118275306173296901779',
#   'unixReviewTime': 1302818783,
#   'reviewTime': 'Apr 14, 2011',
#   'gPlusUserId': '100003840837471130074'},
#  {'rating': 5.0,
#   'reviewerName': 'Enriqueta Powell',
#   'reviewText': 'Arthur Murray Rocklin is an amazing, safe and fun place to dance. The teachers are so wonderful. I love Arthur Murray Rocklin!',
#   'categories': ['Dance School', 'Ballroom', 'Ballroom Dance Instructor'],
#   'gPlusPlaceId': '100303666886894537983',
#   'unixReviewTime': 1392052069,
#   'reviewTime': 'Feb 10, 2014',
#   'gPlusUserId': '100004040064923651839'},
#  {'rating': 5.0,
#   'reviewerName': 'Enriqueta Powell',
#   'reviewText': 'Our car had engine light on plus trck light on - we were on vacation . Dave had the problem diagnosed part ordered from SF repairs completed. Excellent serice. We own 2 Toyotas - so appreciated the effort here in SLT.',
#   'categories': ['Toyota Dealer', 'Used Car Dealer', 'Used Truck Dealer'],
#   'gPlusPlaceId': '100972411849904252912',
#   'unixReviewTime': 1386180686,
#   'reviewTime': 'Dec 4, 2013',
#   'gPlusUserId': '100004040064923651839'},
#  {'rating': 5.0,
#   'reviewerName': 'Enriqueta Powell',
#   'reviewText': 'Frank Moayed is an exceptional salesman. The purchase went very smooth, there was no lengthy negotiating back and forth -He just made it happen.',
#   'categories': ['Mercedes Benz Dealer'],
#   'gPlusPlaceId': '106245091751921986605',
#   'unixReviewTime': 1384468636,
#   'reviewTime': 'Nov 14, 2013',
#   'gPlusUserId': '100004040064923651839'},
#  {'rating': 4.0,
#   'reviewerName': 'Enriqueta Powell',
#   'reviewText': "Chris is the best apartment manager I've had in a very long time. He promptly responds to all issues.",
#   'categories': ['Property Management Company', 'Apartment Rental Agency'],
#   'gPlusPlaceId': '116565227015325093717',
#   'unixReviewTime': 1388775169,
#   'reviewTime': 'Jan 3, 2014',
#   'gPlusUserId': '100004040064923651839'},
#  {'rating': 4.0,
#   'reviewerName': 'Enriqueta Powell',
#   'reviewText': "The most wonderful person you have, a great employee you have, she's wonderful.",
#   'categories': ['Facial Spa', 'Nail Salon', 'Waxing Hair Removal Service'],
#   'gPlusPlaceId': '118255475267806188818',
#   'unixReviewTime': 1385406615,
#   'reviewTime': 'Nov 25, 2013',
#   'gPlusUserId': '100004040064923651839'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar & Grill'],
#   'gPlusPlaceId': '100130838696633414443',
#   'unixReviewTime': 1289986370,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Restaurant', 'European Restaurant', 'American Restaurant'],
#   'gPlusPlaceId': '100331759449029213229',
#   'unixReviewTime': 1289985453,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Japanese Grocery Store'],
#   'gPlusPlaceId': '100369931517856304993',
#   'unixReviewTime': 1289985954,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Thai Restaurant',
#    'Asian Restaurant',
#    'Southeast Asian Restaurant'],
#   'gPlusPlaceId': '100440450148684036722',
#   'unixReviewTime': 1289986267,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['German Restaurant', 'European Restaurant'],
#   'gPlusPlaceId': '100569621166250694738',
#   'unixReviewTime': 1289985371,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Hamburger Restaurant',
#    'American Restaurant',
#    'Fast Food Restaurant'],
#   'gPlusPlaceId': '100627854118617322087',
#   'unixReviewTime': 1289987677,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Portuguese Restaurant'],
#   'gPlusPlaceId': '100643526446716006277',
#   'unixReviewTime': 1289986990,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Gift Shop', 'Book Store', 'Video Store'],
#   'gPlusPlaceId': '100664707178553592562',
#   'unixReviewTime': 1289987340,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Book Store', 'Book Publisher'],
#   'gPlusPlaceId': '100693334925496162046',
#   'unixReviewTime': 1289985755,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar'],
#   'gPlusPlaceId': '100890384150416378747',
#   'unixReviewTime': 1289987598,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Night Club'],
#   'gPlusPlaceId': '101104232990924850129',
#   'unixReviewTime': 1289985482,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Diner', 'American Restaurant', 'Coffee Shop'],
#   'gPlusPlaceId': '101304889618792568567',
#   'unixReviewTime': 1289985682,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Book Store', 'Greeting Card Shop'],
#   'gPlusPlaceId': '101443835545075765956',
#   'unixReviewTime': 1289985762,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Restaurant',
#    'Czech Restaurant',
#    'Eastern European Restaurant'],
#   'gPlusPlaceId': '101579463591032145369',
#   'unixReviewTime': 1289986219,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar'],
#   'gPlusPlaceId': '101621684973226556899',
#   'unixReviewTime': 1289987588,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Movie Theater'],
#   'gPlusPlaceId': '101631524088891597048',
#   'unixReviewTime': 1291268891,
#   'reviewTime': 'Dec 1, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Hamburger Restaurant', 'Fast Food Restaurant'],
#   'gPlusPlaceId': '101781241041932948839',
#   'unixReviewTime': 1289987712,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Park', 'Playground', 'Tennis Court'],
#   'gPlusPlaceId': '101941796764402055058',
#   'unixReviewTime': 1289986391,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Acupuncture Clinic'],
#   'gPlusPlaceId': '102080485967927224314',
#   'unixReviewTime': 1289985969,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Hamburger Restaurant',
#    'Fast Food Restaurant',
#    'American Restaurant'],
#   'gPlusPlaceId': '102094598351860678225',
#   'unixReviewTime': 1289987749,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Sandwich Shop', 'Asian Restaurant', 'Fast Food Restaurant'],
#   'gPlusPlaceId': '102100098208019707248',
#   'unixReviewTime': 1289984635,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Coffee Shop'],
#   'gPlusPlaceId': '102131351364718142915',
#   'unixReviewTime': 1289985226,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': 'Authentic curry katsu, a bit pricey but it tastes like home.',
#   'categories': ['Japanese Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '102172799305238492331',
#   'unixReviewTime': 1307423466,
#   'reviewTime': 'Jun 6, 2011',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Californian Restaurant', 'American Restaurant'],
#   'gPlusPlaceId': '102202074924013542239',
#   'unixReviewTime': 1291269546,
#   'reviewTime': 'Dec 1, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Coffee Shop', 'Dessert Shop', 'Donut Shop'],
#   'gPlusPlaceId': '102257640971308716925',
#   'unixReviewTime': 1301828085,
#   'reviewTime': 'Apr 3, 2011',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar'],
#   'gPlusPlaceId': '102300951493082533315',
#   'unixReviewTime': 1289986797,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Belgian Restaurant', 'European Restaurant', 'Store'],
#   'gPlusPlaceId': '102343331512826387756',
#   'unixReviewTime': 1289986325,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Book Store', 'Used Book Store'],
#   'gPlusPlaceId': '102625616514634752609',
#   'unixReviewTime': 1289985764,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Stores and Shopping', 'Hardware Store'],
#   'gPlusPlaceId': '102634220530164956301',
#   'unixReviewTime': 1289985996,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Night Club', 'Cafe', 'Gay Bar'],
#   'gPlusPlaceId': '103013380214607560963',
#   'unixReviewTime': 1289986794,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Asian Restaurant',
#    'Southeast Asian Restaurant',
#    'Vietnamese Restaurant'],
#   'gPlusPlaceId': '103027295393367071017',
#   'unixReviewTime': 1289987516,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Belgian Restaurant', 'European Restaurant'],
#   'gPlusPlaceId': '103045694943852272953',
#   'unixReviewTime': 1289984934,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar', 'Restaurant', 'Coffee Shop'],
#   'gPlusPlaceId': '103113550267657156862',
#   'unixReviewTime': 1291268970,
#   'reviewTime': 'Dec 1, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Gourmet Grocery Store',
#    'Vitamin & Supplements Store',
#    'Health Food Store'],
#   'gPlusPlaceId': '103329562044306939691',
#   'unixReviewTime': 1289987122,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Sandwich Shop', 'Fast Food Restaurant'],
#   'gPlusPlaceId': '103520476731292467944',
#   'unixReviewTime': 1289987960,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Book Store', 'Used Book Store'],
#   'gPlusPlaceId': '103598338975007962828',
#   'unixReviewTime': 1289986665,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Vietnamese Restaurant',
#    'Asian Restaurant',
#    'Southeast Asian Restaurant'],
#   'gPlusPlaceId': '103766723363958372565',
#   'unixReviewTime': 1289987381,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Cocktail Bar'],
#   'gPlusPlaceId': '103817100250089867220',
#   'unixReviewTime': 1289984919,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar'],
#   'gPlusPlaceId': '103894515121115434227',
#   'unixReviewTime': 1289987575,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Pakistani Restaurant',
#    'Asian Restaurant',
#    'South Asian Restaurant'],
#   'gPlusPlaceId': '104019729968290348116',
#   'unixReviewTime': 1301826786,
#   'reviewTime': 'Apr 3, 2011',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Japanese Restaurant', 'Asian Restaurant', 'Bar'],
#   'gPlusPlaceId': '104184946228909051562',
#   'unixReviewTime': 1289984563,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Pizza Restaurant', 'Wine Bar'],
#   'gPlusPlaceId': '104208264997124296574',
#   'unixReviewTime': 1289985334,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Italian Grocery Store'],
#   'gPlusPlaceId': '104234225548368618197',
#   'unixReviewTime': 1289987966,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Pizza Restaurant'],
#   'gPlusPlaceId': '104265919008409205759',
#   'unixReviewTime': 1289984930,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Vietnamese Restaurant',
#    'Asian Restaurant',
#    'Southeast Asian Restaurant'],
#   'gPlusPlaceId': '104320550578710821192',
#   'unixReviewTime': 1289987501,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Seafood Restaurant', 'Vietnamese Restaurant'],
#   'gPlusPlaceId': '104382138284495756930',
#   'unixReviewTime': 1289987930,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Cheesesteak Restaurant',
#    'American Restaurant',
#    'Fast Food Restaurant'],
#   'gPlusPlaceId': '104388986163727783882',
#   'unixReviewTime': 1289987984,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Chinese Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '104427978812015513390',
#   'unixReviewTime': 1289984685,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Movie Theater', 'Dinner Theater'],
#   'gPlusPlaceId': '104443216790055508247',
#   'unixReviewTime': 1289986031,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Book Store', 'Gift Shop'],
#   'gPlusPlaceId': '104448906467288460932',
#   'unixReviewTime': 1289985778,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Book Store'],
#   'gPlusPlaceId': '104572235432129840866',
#   'unixReviewTime': 1289985795,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Sushi Restaurant', 'Asian Restaurant'],
#   'gPlusPlaceId': '104599764729926803486',
#   'unixReviewTime': 1289988315,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['American Restaurant'],
#   'gPlusPlaceId': '104658248417245594515',
#   'unixReviewTime': 1289985429,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Coffee Shop'],
#   'gPlusPlaceId': '104743172009835954981',
#   'unixReviewTime': 1301827598,
#   'reviewTime': 'Apr 3, 2011',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['American Restaurant'],
#   'gPlusPlaceId': '104754318057276946457',
#   'unixReviewTime': 1289985368,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Diner', 'American Restaurant', 'Fast Food Restaurant'],
#   'gPlusPlaceId': '104814002235630299046',
#   'unixReviewTime': 1289985434,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar & Grill', 'Live Music Venue'],
#   'gPlusPlaceId': '105112554202154972433',
#   'unixReviewTime': 1289987590,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Public Library'],
#   'gPlusPlaceId': '105369682299420794294',
#   'unixReviewTime': 1289986598,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Pizza Restaurant',
#    'European Restaurant',
#    'Italian Restaurant'],
#   'gPlusPlaceId': '105566901076930544921',
#   'unixReviewTime': 1289988193,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Nightlife', 'Comedy Club', 'Brunch Restaurant'],
#   'gPlusPlaceId': '105662049826268018998',
#   'unixReviewTime': 1291268993,
#   'reviewTime': 'Dec 1, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar', 'Sports Bar'],
#   'gPlusPlaceId': '105715562929655051674',
#   'unixReviewTime': 1289986785,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Chicken Restaurant', 'Fast Food Restaurant'],
#   'gPlusPlaceId': '105805479336772498607',
#   'unixReviewTime': 1289986292,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Japanese Restaurant', 'Sushi Restaurant'],
#   'gPlusPlaceId': '105921299261007316802',
#   'unixReviewTime': 1289984616,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Cafe', 'Hamburger Restaurant', 'Sandwich Shop'],
#   'gPlusPlaceId': '105932545125916763954',
#   'unixReviewTime': 1291268957,
#   'reviewTime': 'Dec 1, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['German Restaurant', 'European Restaurant', 'Banquet Hall'],
#   'gPlusPlaceId': '106222304716873537270',
#   'unixReviewTime': 1289986213,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['American Restaurant', 'Bar'],
#   'gPlusPlaceId': '106225819574943153874',
#   'unixReviewTime': 1289985364,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Chinese Restaurant', 'Asian Restaurant', 'Bakery'],
#   'gPlusPlaceId': '106298480640235493880',
#   'unixReviewTime': 1289985896,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 3.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bar', 'Night Club', 'Cocktail Bar'],
#   'gPlusPlaceId': '106313978976656033473',
#   'unixReviewTime': 1301828251,
#   'reviewTime': 'Apr 3, 2011',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Art Museum'],
#   'gPlusPlaceId': '106403808789200126545',
#   'unixReviewTime': 1289983994,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Stores and Shopping', 'Book Store'],
#   'gPlusPlaceId': '106485867138256683018',
#   'unixReviewTime': 1289985801,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Irish Pub'],
#   'gPlusPlaceId': '106488366744499106941',
#   'unixReviewTime': 1289984747,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Middle Eastern Restaurant', 'Deli', 'Sandwich Shop'],
#   'gPlusPlaceId': '106579463539993327186',
#   'unixReviewTime': 1289984727,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Bakery', 'Cheese Shop'],
#   'gPlusPlaceId': '106586259444096937664',
#   'unixReviewTime': 1289988238,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Hamburger Restaurant',
#    'Fast Food Restaurant',
#    'Takeout Restaurant'],
#   'gPlusPlaceId': '106657922004310165898',
#   'unixReviewTime': 1289986489,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Cheesesteak Restaurant',
#    'American Restaurant',
#    'Sandwich Shop'],
#   'gPlusPlaceId': '106779703113407343157',
#   'unixReviewTime': 1289986320,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Vietnamese Restaurant',
#    'Asian Restaurant',
#    'Southeast Asian Restaurant'],
#   'gPlusPlaceId': '106887199399707448123',
#   'unixReviewTime': 1289984901,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Hamburger Restaurant',
#    'Fast Food Restaurant',
#    'American Restaurant'],
#   'gPlusPlaceId': '107181286454000040902',
#   'unixReviewTime': 1291269246,
#   'reviewTime': 'Dec 1, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Japanese Restaurant',
#    'Ramen Restaurant',
#    'Sushi Restaurant'],
#   'gPlusPlaceId': '107182017792588792193',
#   'unixReviewTime': 1289984533,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Mediterranean Restaurant', 'Deli'],
#   'gPlusPlaceId': '107267993520557276716',
#   'unixReviewTime': 1289984720,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Coffee Shop', 'Espresso Bar'],
#   'gPlusPlaceId': '107324858244614724698',
#   'unixReviewTime': 1289988044,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Vietnamese Restaurant',
#    'Asian Restaurant',
#    'Southeast Asian Restaurant'],
#   'gPlusPlaceId': '107625205511686922236',
#   'unixReviewTime': 1289987940,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 5.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
#   'categories': ['Stores and Shopping', 'Dessert Shop', 'Donut Shop'],
#   'gPlusPlaceId': '107650127296110974607',
#   'unixReviewTime': 1289987610,
#   'reviewTime': 'Nov 17, 2010',
#   'gPlusUserId': '100008176682616801686'},
#  {'rating': 4.0,
#   'reviewerName': 'Roy Watts',
#   'reviewText': None,
# ...
#   'categories': ['Gastropub'],
#   'gPlusPlaceId': '107486195923414103512',
#   'unixReviewTime': 1381937504,
#   'reviewTime': 'Oct 16, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 4.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': "Great place for weekend brunch.  Items on the menu vary yet are unique.  I ordered the hazelnut pancakes with marion berry compote and a side of Oregon pepper bacon.  So delicious!  They also have Dutch baby on the menu so if you're looking for a place that makes it, Plum's is your place.  Other items that are great to order are: fresh berry waffles, coconut French toast, omelettes, and mimosas.  There's a $8 brunch add on option that allows for tea, coffee, and a glass of mimosa.  Get there early and avoid the crowds.  Today after 10:20 am, we had a 15 minute wait.  It can get up to an hour on the weekends.  Our service was great.  I left pleasantly full and was happy with my experience.",
#   'categories': ['American Restaurant'],
#   'gPlusPlaceId': '108010261707983464834',
#   'unixReviewTime': 1381937712,
#   'reviewTime': 'Oct 16, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 5.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': "One of the best meals I've had in a long time. The tables are covered in white tablecloths and the glasses sparkling.  Fancy, schmancy.    We ordered the Mahi Mahi and the seared Ahi. Both were cooked to perfection. The fish was just the right texture and color. Everything on the plate complemented the fish perfectly, down to the sauce.  The peppery arugula salad and the lemon cous cous was perfect with the crispy pan seared Mahi Mahi.  The spinach, sushi rice, and roasted vegetables were a great addition to the seared Ahi.  The teriyaki  and wasabi sauce was delicious with the Ahi.    We came early here on a Sunday evening before a show and found the dining room bustling.  The waiters were busy.  Recession?  What recession?  The crowd was definitely older and we felt like we were the youngest diners in the room.  It's too bad we had a show to catch, otherwise we would have ordered dessert.",
#   'categories': ['Restaurant', 'Brunch Restaurant', 'Live Music Venue'],
#   'gPlusPlaceId': '108549238477881511644',
#   'unixReviewTime': 1381938141,
#   'reviewTime': 'Oct 16, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 3.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': "3.5 stars.  My cousin Vanessa D. and I decided to walk over to Haute Cakes Caffe from her apartment for brunch on Sunday.  I arrived at her place around 11:40 am so by the time we got there it was close to noon.  There was plenty of seating and they were still serving breakfast items.  I guess seating can be scarce during peak hours but we didn't experience that while we were there.  Also, there was a sign up stating that they don't serve lunch menu items on Sunday, possibly because most people come for Sunday brunch.    We both ordered the Haute combination ($9.75) which includes pancakes or french toast, your choice of bacon or sausage, fresh fruit, and 2 eggs any way you like it.  We both upgraded ($2) to blueberry cornmeal pancakes and orange ricotta pancakes respectively.  I also ordered a medium sized fresh squeezed orange juice ($2.25; think Naked, not Tropicana) and she had a medium sized iced tea ($2.50).  I ordered my eggs scrambled and my cousin had hers over easy.  The food took a while to come out.  We were starving.    The food was definitely pleasing to the eye when it arrived and tasty as well.  The orange ricotta pancakes are very soft, due to the ricotta cheese and my blueberry cornmeal pancakes reminded me of cornbread, which I loved.  The orange ricotta pancakes also come with macerated fruit in addition to syrup.  I'm just wondering if maybe they forgot mine?  It would have definitely heightened my star rating for this place had I received extra fruit for my pancakes.  The bacon was crispy and the fruit varied from plate to plate.  I had watermelon, pineapple, and an orange slice while Vanessa got a sliced peach, watermelon, and orange.  The food is good, maybe above average but definitely overpriced.  I might be persuaded to come back to try other items off of the menu, but not for awhile.",
#   'categories': ['Cafe', 'Bakery'],
#   'gPlusPlaceId': '109516461075595720330',
#   'unixReviewTime': 1381937745,
#   'reviewTime': 'Oct 16, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 5.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': 'My most recent experience with Cucina Enoteca involved planning a retirement party for my former bosses.  We had 90 people or so and Carmelle (events coordinator) was a breeze to work with.  We had a budget we wanted to stick with and we actually came a little under so we were able to wrap up a few bottles of wine and champagne to give to the couple too.  The food was amazing as always and the service was excellent.  Thank you to Cucina Enoteca for always being better than the rest.',
#   'categories': ['Italian Restaurant', 'European Restaurant', 'Wine Store'],
#   'gPlusPlaceId': '110587132930571604314',
#   'unixReviewTime': 1381422690,
#   'reviewTime': 'Oct 10, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 5.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': "Another amazing visit to the Playground, this time for Sunday Supper and it was fantastic.  Compliments to Jason Quinn and his amazing staff.  The Playground is hands down one of my favorite restaurants in OC.  We were full upon leaving and I was so happy to have been able to share it with some of my friends.  Thanks again to everyone who attended and to the wonderful staff at the Playground.  Our Sunday Supper was $40 per person and that already includes tax + gratuity.  They brought out plate after plate of delicious and amazing food.  I couldn't have been happier with my experience and my friends echoed the same sentiments.    We had cauliflower nachos, corn, broccolini, jicama salad, artichoke risotto, blue crab, asparagus, wagyu beef buns, quail, beet salad, fried chicken, pork belly stuffed cannelloni, maple glazed pork chop, grapefruit sorbet, and sticky toffee pudding.  I may have forgotten a dish, but it was all amazing and delicious.  They will bring out more of a dish you can't get enough of but we were so ridiculously full that we cried uncle.  For Sunday Supper, it is by reservation only and the max group size is 10.  They charge your credit card in advance to secure your reservation but it is worth every penny.  Plan it a month in advance for a large party but you might be able to squeeze in a smaller group within a few weeks time frame.  It depends on how full their reservation book is.  Don't forget, there's no corkage fee and you can bring your own wine or beer to accompany your dinner.",
#   'categories': ['New American Restaurant', 'Bar', 'Small Plates Restaurant'],
#   'gPlusPlaceId': '112468534046539384913',
#   'unixReviewTime': 1381937470,
#   'reviewTime': 'Oct 16, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 5.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': "The food here is extraordinary.  My date and I had each ordered from the tasting menu.  I had the seasonal menu, while he ordered the traditional one.  Seasonal Menu: First dish ~ Fresh Wild Seabass Ceviche on a Wonton Crisp with Sweet Soy & Micro Greens.  Paired with a 2009 Kung Fu Girl Riesling, Washington State.  The seabass ceviche was delicious with the microgreens and sweet soy sauce.  The plating was beautiful, but I did not hesitate to dig in.  It's a good thing I took a photo beforehand.  The wonton gave it a nice crunch.  The riesling rounded out the sweetness of the dish providing a dry note to the whole experience.  I was very pleased with this dish.  4.5 stars.  Second dish ~ Proscuitto Wrapped, Panko Crusted Fried Green Tomato & Fresh Sweet Creamed Corn, Garnished with Queso Fresco.  Paired with a 2009 Tintero Moscato d'Asti, Italy.  This was absolutely AMAZING.  I was blown away by the simplicity. yet complex arrangement of flavors and textures in this dish.  The crunchiness of the panko with the soft, sweet corn brought a slight tear to my eye.  I was in HEAVEN.  The salty proscuitto paired with the sweet corn and Moscato d'Asti made a little party in my mouth.  By far my favorite dish of the night.  5 stars.  Third dish ~ All Natural Quail on a bed of White Bean Puree with Spanish Chorizo, drizzled with a Strawberry Balsamic Reduction.  Paired with a 2008 Castillo de Monjardin Tintico, Navarra Spain.  This was delicious but I wasn't as enamored with it as the other two dishes.  The wine was spicy which brought about an interesting addition to the quail and puree.  Again it was good, but not my favorite.  3.5 stars.    Final dish ~ Fresh Baked Oatmeal Raisin Cookie with House Made Vanilla Moscatel Ice Cream.  Paired with a N.V. Adega de Favaios Moscatel do Douro, Portugal.  This was a small bite but very indulgent nonetheless.  The warm cookie with the ice cream when well with the moscatel wine.  It was so GOOD.  4 stars.    Traditional menu: First dish ~  Sautéed Sea Scallop on a nest of Crispy Fried Yucca finished with Tarragon Chardonnay Sauce.  Paired with a 2006 Frogmore Creek Chardonnay, Tasmania.  My date really enjoyed this.  I'm not a fan of scallops in general, possibly because I've never had great scallops.  But these were delicious!  They were cooked perfectly with a beautiful caramelized sear.  They were sweet and succulent. The dry chardonnay rounded out the sweetness of the scallops nicely.  Very good.  4.5 stars.    Second dish ~ Handmade Fettuccini Pomodoro garnished with Aged Pecorino Romano Cheese.  Paired with a 2008 Castelvero Barbera, Piedmonte Italy.  This fettuccini pomodoro was delicate and tender.  It went well with the barbera wine.  My date liked it but said it was just ok.  4 stars.  Third dish ~ Four Ounces of All Natural Filet Mignon & Crispy Fried Onions with Bleu Des Basque Demi Cream Sauce.  Paired with a 2008 Maipe Cabernet Sauvignon, Argentina.  This was by far the best dish on the menu.  The steak was so tender that with just a butter knife, it gave way so easily.  The crispy onions were so good with the filet.  The cabernet rounded out the dish nicely.  5 stars.    Final dish ~ Grandma's Cheesecake, Wild Berry Puree.  Paired with a NV Ferreira Ruby Port.  A wonderful end to a great menu.  The cheesecake was the perfect size to finish off the meal.  It was slightly rich but paired with the puree and fresh fruit, it was delicious along with the port.  4 stars.   We had a fantastic meal.  I'm amazed at the quality of the food, service, and ambiance.  This is definitely one of the BEST restaurants, if not a best kept dining secret in the OC.",
#   'categories': ['Eclectic Restaurant',
#    'European Restaurant',
#    'Italian Restaurant'],
#   'gPlusPlaceId': '112554535826309729839',
#   'unixReviewTime': 1381937668,
#   'reviewTime': 'Oct 16, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 5.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': "I've been to Mastro's Ocean Club and I loved it.  I haven't tried the steak at this location but I have it on very good authority that it's pretty damn delicious.  The other evening while having dinner across the street, Chris K. and I decided that we wanted dessert but not just any dessert.  We wanted butter cake from Mastro's.  Yes, ooey, gooey, butter cake with ice cream and fresh whipped cream.  Again, I'd never had it before and I've heard it was really good.  You never know unless you try it, right?  So we walked across the street from Pizzeria Ortica and made our way into Mastro's.    We asked for a table for 2 and they escorted us to a dining room with dim lighting.  We ended up in a half booth which was perfect.  It's dark and romantic but who were we kidding, we were there for just dessert.  Do tell the waiter that you just want the dessert menu to avoid wasting his time and yours.  We perused the list but butter cake was our objective.  It's $15 and worth every penny.  This portion can easily feed 4 people after a massive steak feast.  Since it was just the two of us we polished off a good amount before admitting defeat.  The cake is definitely gooey in the center but the outside was a little crumbly and dry.  The ice cream and fresh whipped cream worked really well.  They even garnished it with a few strawberries too.  Delicious.  Even if you're not there for steak, you can still have dessert.",
#   'categories': ['Steak House', 'Fine Dining Restaurant'],
#   'gPlusPlaceId': '113791579111931551034',
#   'unixReviewTime': 1381938318,
#   'reviewTime': 'Oct 16, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 5.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': 'I went here for my birthday and the food was fantastic.  We had steak and salmon with potatoes au gratin and sauteed asparagus on the side.  It was delicious.  The steak was like butter in your mouth.  It was so tender.  The salmon was perfectly cooked to medium rare.  Everything was yummy.  The cantaloupe martini was great and they give you the shaker so you can continue to pour yourself the entire drink.  The creme brulee with fresh berries was to die for.  The service was exceptional and the view of the ocean amazing.  It was a great dining experience.',
#   'categories': ['Seafood Restaurant', 'Bar', 'Steak House'],
#   'gPlusPlaceId': '116366019898338513740',
#   'unixReviewTime': 1381938261,
#   'reviewTime': 'Oct 16, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  {'rating': 4.0,
#   'reviewerName': 'Trina D.',
#   'reviewText': "I had been lusting over some foodie photos taken at the Federal Bar in Long Beach for months.  Then one day, I saw a LivingSocial deal for brunch.  Of course, online coupons can be hit or miss but all those blog photos can't be wrong.  I bought the deal which included 2 entrees and bottomless mimosas.  I don't know about you but I'm not going to pass up bottomless mimosas.  No way.    So last Sunday, my friend Julie B. and I went to the Federal Bar for brunch to celebrate her birthday.  She was super excited because she had no idea what we were doing for brunch.  We walked in to give our name to the hostess and we're ushered into the large, spacious dining room.  The Federal Bar is located inside an old bank so it has high ceilings and a gorgeous art deco interior.  The staff is dressed up in 1920s clothing circa the Great Gatsby.  This place would be awesome for a party!  Our server came by and took our orders for the mimosas and my LivingSocial certificate.    I ordered the red velvet waffle sandwich but was informed that they had run out of waffles.  TRAGEDY!  Especially since they had just been open an hour when we walked in.  The waitress suggested the breakfast burger which also had the sweet and savory combination I was looking for.  Julie ordered the omelette with short rib.  Our entrees came out shortly after and I have to say their food is so delicious!  The burger was perfectly cooked to order.  I asked for medium.  The maple aioli was a nice touch and I loved the heirloom tomatoes.  The French fries were covered in parmesan and parsley but so tasty.  Julie really liked her omelette as well and ate the entire thing.  My mimosa glass was constantly refilled to the point where I had to ask her to stop filling it because I had to drive.  I'd definitely come back here for brunch.  It's a shame that it's so far away from me though.  I'll also come back to try out their dinner menu as well.  They have a full bar with a few craft cocktails that sound interesting.  I'll definitely be back.",
#   'categories': ['American Restaurant'],
#   'gPlusPlaceId': '117595459688391806695',
#   'unixReviewTime': 1381422721,
#   'reviewTime': 'Oct 10, 2013',
#   'gPlusUserId': '100103275107761217948'},
#  ...]

# %%
places[9]
# Out:
# {'name': 'Nail Perfection',
#  'price': None,
#  'address': ['556 Las Posas Rd', 'Camarillo, CA 93010'],
#  'hours': None,
#  'phone': '(805) 987-0992',
#  'closed': False,
#  'gPlusPlaceId': '100068746766818502566',
#  'gps': [34.218397, -119.069823]}

# %%
reviews[0]
# Out:
# {'rating': 4.0,
#  'reviewerName': 'william spindler',
#  'reviewText': 'Best War Wanton soup in Red Bluff',
#  'categories': ['Asian Restaurant', 'Chinese Restaurant'],
#  'gPlusPlaceId': '106591714648856494903',
#  'unixReviewTime': 1394669496,
#  'reviewTime': 'Mar 12, 2014',
#  'gPlusUserId': '100000032416892623125'}

# %%
wordCount = defaultdict(int)
for d in data:
    if type(d['reviewText']) == str:
        for w in d['reviewText'].split():
            wordCount[w] += 1

# %%
wordCount = defaultdict(int)
punctuation = set(string.punctuation)
for d in data:
    if type(d['reviewText']) == str:
        r = ''.join([c for c in d['reviewText'].lower() if not c in punctuation])
        for w in r.split():
            wordCount[w] += 1

counts = [(wordCount[w], w) for w in wordCount]
counts.sort()
counts.reverse()

# %%
words = [x[1] for x in counts[:1000]]

# %%
# Out:
# ['the',
#  'and',
#  'a',
#  'to',
#  'i',
#  'is',
#  'of',
#  'for',
#  'in',
#  'was',
#  'it',
#  'but',
#  'you',
#  'food',
#  'good',
#  'with',
#  'great',
#  'this',
#  'place',
#  'are',
#  'they',
#  'that',
#  'on',
#  'my',
#  'have',
#  'not',
#  'very',
#  'its',
#  'here',
#  'at',
#  'service',
#  'we',
#  'so',
#  'as',
#  'be',
#  'had',
#  'if',
#  'their',
#  'like',
#  'get',
#  'were',
#  'there',
#  'best',
#  'all',
#  'one',
#  'really',
#  'go',
#  'can',
#  'just',
#  'nice',
#  'out',
#  'or',
#  'from',
#  'your',
#  'love',
#  'an',
#  'some',
#  'too',
#  'also',
#  'time',
#  'always',
#  'me',
#  'up',
#  'when',
#  'delicious',
#  'restaurant',
#  'more',
#  'which',
#  'dont',
#  'well',
#  'about',
#  'has',
#  'back',
#  'pretty',
#  'would',
#  'little',
#  'what',
#  'friendly',
#  'by',
#  'staff',
#  'only',
#  'excellent',
#  'our',
#  'will',
#  'been',
#  'amazing',
#  'ive',
#  'menu',
#  'try',
#  'bar',
#  'than',
#  'other',
#  'wait',
#  'pizza',
#  'bit',
#  'chicken',
#  'much',
#  'no',
#  'people',
#  'better',
#  'definitely',
#  'come',
#  'make',
#  'even',
#  'coffee',
#  'worth',
#  'do',
#  'atmosphere',
#  'though',
#  'fresh',
#  'favorite',
#  'selection',
#  'area',
#  'experience',
#  'order',
#  'awesome',
#  'because',
#  'beer',
#  'tasty',
#  'small',
#  'got',
#  'after',
#  'want',
#  'them',
#  'im',
#  'drinks',
#  'lunch',
#  'eat',
#  'recommend',
#  'fun',
#  'long',
#  'way',
#  'most',
#  'us',
#  'everything',
#  'youre',
#  'location',
#  'price',
#  'dinner',
#  'night',
#  'over',
#  'day',
#  'quality',
#  'still',
#  'around',
#  'wine',
#  'spot',
#  'take',
#  'prices',
#  'ever',
#  'friends',
#  'made',
#  'dishes',
#  'went',
#  'find',
#  'san',
#  'first',
#  'burger',
#  'right',
#  'never',
#  'sure',
#  'many',
#  'while',
#  'came',
#  'happy',
#  'lot',
#  'cheese',
#  'could',
#  'every',
#  'any',
#  'think',
#  'going',
#  'meal',
#  'super',
#  'down',
#  'few',
#  'didnt',
#  'sushi',
#  'how',
#  'know',
#  'table',
#  'bad',
#  'cant',
#  'decent',
#  'salad',
#  'places',
#  'two',
#  'special',
#  'big',
#  'before',
#  'quite',
#  'decor',
#  'ordered',
#  'who',
#  'see',
#  'new',
#  'feel',
#  'city',
#  'then',
#  'again',
#  'line',
#  'hour',
#  'times',
#  'he',
#  'sf',
#  'cream',
#  'off',
#  'side',
#  'perfect',
#  'expensive',
#  'sauce',
#  'breakfast',
#  'taste',
#  'did',
#  'something',
#  'since',
#  'fries',
#  'dish',
#  'free',
#  'large',
#  'where',
#  'fish',
#  'parking',
#  'nothing',
#  'drink',
#  'room',
#  'work',
#  'wonderful',
#  'sandwich',
#  'fast',
#  'fantastic',
#  'say',
#  'both',
#  'fried',
#  'usually',
#  'especially',
#  'enjoy',
#  'meat',
#  'bread',
#  'enough',
#  'outside',
#  'next',
#  'into',
#  'ok',
#  'need',
#  'cool',
#  'ice',
#  'brunch',
#  'francisco',
#  'seating',
#  'bay',
#  '2',
#  'looking',
#  'am',
#  'view',
#  'being',
#  'crowded',
#  'thing',
#  'hot',
#  'huge',
#  'sweet',
#  'cheap',
#  'now',
#  'tried',
#  'portions',
#  'pork',
#  'visit',
#  'spicy',
#  'overall',
#  'theres',
#  'busy',
#  'old',
#  'soup',
#  'restaurants',
#  'top',
#  'wasnt',
#  'high',
#  'quick',
#  'however',
#  'lots',
#  'during',
#  'probably',
#  'she',
#  'burgers',
#  'tea',
#  'store',
#  '3',
#  'must',
#  'rice',
#  'open',
#  'different',
#  'once',
#  'pricey',
#  'inside',
#  'home',
#  'give',
#  'id',
#  'options',
#  'thai',
#  'la',
#  'beautiful',
#  'thats',
#  'years',
#  'helpful',
#  'style',
#  'full',
#  'sandwiches',
#  'makes',
#  'kind',
#  'flavor',
#  'italian',
#  'things',
#  'beef',
#  'chocolate',
#  'family',
#  'loved',
#  '5',
#  'dining',
#  'should',
#  'hard',
#  'street',
#  'highly',
#  'french',
#  'clean',
#  'away',
#  'coming',
#  'sit',
#  'local',
#  'music',
#  'everyone',
#  'town',
#  'check',
#  'minutes',
#  'actually',
#  'enjoyed',
#  'else',
#  'park',
#  'without',
#  'interesting',
#  'mexican',
#  'another',
#  'bring',
#  'tables',
#  'took',
#  'neighborhood',
#  'same',
#  'youll',
#  'such',
#  'authentic',
#  'flavors',
#  'shop',
#  'last',
#  'far',
#  'expect',
#  'those',
#  'look',
#  'steak',
#  'ramen',
#  'variety',
#  'served',
#  'house',
#  'car',
#  'anything',
#  'space',
#  'isnt',
#  'beers',
#  'each',
#  'dessert',
#  'getting',
#  'items',
#  'reasonable',
#  'found',
#  'list',
#  'group',
#  'garlic',
#  'indian',
#  '4',
#  'walk',
#  'whole',
#  'ambiance',
#  'ask',
#  'used',
#  'unique',
#  'these',
#  'said',
#  'end',
#  'hotel',
#  'yummy',
#  'through',
#  'friend',
#  'done',
#  'her',
#  'although',
#  'real',
#  'cocktails',
#  'prepared',
#  'live',
#  'early',
#  'almost',
#  'easy',
#  'chinese',
#  'eating',
#  'might',
#  'seafood',
#  'close',
#  'thank',
#  'often',
#  'why',
#  'sometimes',
#  'okay',
#  'stop',
#  'late',
#  'theyre',
#  'hours',
#  'cafe',
#  'kids',
#  'slow',
#  'burrito',
#  'average',
#  'ingredients',
#  'stars',
#  'gets',
#  'part',
#  'couple',
#  'serve',
#  '10',
#  'noodles',
#  'least',
#  'less',
#  'overpriced',
#  'patio',
#  'solid',
#  'may',
#  'absolutely',
#  'having',
#  'warm',
#  '1',
#  'fine',
#  'value',
#  'doesnt',
#  'vegetarian',
#  'extremely',
#  'cooked',
#  'stuff',
#  'tacos',
#  'door',
#  'grab',
#  'wanted',
#  'maybe',
#  'liked',
#  'watch',
#  'does',
#  'priced',
#  'his',
#  'own',
#  'use',
#  'course',
#  'wont',
#  'plus',
#  'care',
#  'seems',
#  'japanese',
#  'put',
#  'customer',
#  'packed',
#  'half',
#  'loud',
#  'fan',
#  'comes',
#  'date',
#  'wrong',
#  'rolls',
#  'choice',
#  'attentive',
#  'waiting',
#  'thought',
#  'outdoor',
#  'front',
#  'crab',
#  'water',
#  'pasta',
#  'deal',
#  'keep',
#  'ill',
#  'crowd',
#  'tasted',
#  'plate',
#  'party',
#  'weekend',
#  'trying',
#  'bacon',
#  'plenty',
#  'either',
#  'extra',
#  'yet',
#  'shrimp',
#  'bbq',
#  'chips',
#  'disappointed',
#  'casual',
#  'job',
#  'egg',
#  'beach',
#  'simple',
#  'person',
#  'stay',
#  'tasting',
#  'recommended',
#  'wish',
#  'pay',
#  'comfortable',
#  'perfectly',
#  'buy',
#  'able',
#  'curry',
#  'quickly',
#  'miss',
#  'cold',
#  'mission',
#  'views',
#  'week',
#  'several',
#  'show',
#  'help',
#  'lines',
#  'left',
#  'near',
#  'money',
#  'downtown',
#  'grilled',
#  'roll',
#  'let',
#  'days',
#  'cute',
#  'yes',
#  'vibe',
#  'etc',
#  'cake',
#  'three',
#  'reservation',
#  'size',
#  'world',
#  'dim',
#  'felt',
#  'plates',
#  'main',
#  'salads',
#  'oh',
#  'business',
#  'asked',
#  'light',
#  'gave',
#  'call',
#  'name',
#  'pleasant',
#  'sunday',
#  'second',
#  'crust',
#  'popular',
#  'wife',
#  'reservations',
#  'offer',
#  'flavorful',
#  'outstanding',
#  'classic',
#  'point',
#  'kitchen',
#  'weekends',
#  'rather',
#  'wouldnt',
#  'sum',
#  'red',
#  'pick',
#  'green',
#  'typical',
#  'bowl',
#  'making',
#  'pizzas',
#  'server',
#  'regular',
#  'eggs',
#  'available',
#  'short',
#  'lovely',
#  'looks',
#  'seat',
#  'evening',
#  'potato',
#  'someone',
#  'cuisine',
#  'waiter',
#  'seem',
#  'appetizers',
#  'across',
#  '20',
#  'professional',
#  'lamb',
#  'year',
#  'rooms',
#  'mind',
#  'counter',
#  'incredible',
#  'mediocre',
#  'tastes',
#  'standard',
#  'itself',
#  'leave',
#  'choices',
#  'california',
#  'wifi',
#  'desserts',
#  'de',
#  'appetizer',
#  'star',
#  'between',
#  'along',
#  'knowledgeable',
#  'duck',
#  'reason',
#  'morning',
#  'glass',
#  'seemed',
#  'yourself',
#  'amount',
#  'salmon',
#  'bite',
#  'trip',
#  'game',
#  'remember',
#  'instead',
#  'havent',
#  'guys',
#  'until',
#  'cozy',
#  'market',
#  'fancy',
#  'noisy',
#  'crispy',
#  'salsa',
#  'totally',
#  'portion',
#  'servers',
#  'told',
#  'hit',
#  'anyone',
#  'bland',
#  'dry',
#  'owner',
#  'foods',
#  'die',
#  'waitress',
#  'chef',
#  'brought',
#  'run',
#  'located',
#  'healthy',
#  'building',
#  'thanks',
#  'creative',
#  'option',
#  'life',
#  'joint',
#  'impressed',
#  'seated',
#  'start',
#  'given',
#  'avoid',
#  'sitting',
#  'saturday',
#  'choose',
#  'needs',
#  'looked',
#  'shopping',
#  'pie',
#  'tell',
#  'him',
#  'limited',
#  'fare',
#  'wines',
#  'beans',
#  'valley',
#  'movie',
#  'white',
#  'others',
#  'expected',
#  'traditional',
#  'ordering',
#  'toast',
#  'seen',
#  'yum',
#  'veggie',
#  'south',
#  'couldnt',
#  'hungry',
#  '15',
#  'birthday',
#  'ones',
#  'slightly',
#  'burritos',
#  'pho',
#  'ate',
#  'modern',
#  'including',
#  'floor',
#  'walking',
#  'specials',
#  'milk',
#  'vegan',
#  'favorites',
#  'review',
#  'myself',
#  'rest',
#  'wall',
#  'needed',
#  'under',
#  'fairly',
#  'cash',
#  'broth',
#  'cup',
#  'return',
#  'truly',
#  'feels',
#  'fact',
#  'tofu',
#  'arent',
#  'hang',
#  'tiny',
#  'otherwise',
#  'art',
#  'reviews',
#  'above',
#  'spend',
#  'share',
#  'butter',
#  '6',
#  'surprised',
#  'office',
#  'add',
#  'treat',
#  'nearby',
#  'later',
#  'convenient',
#  'american',
#  'toppings',
#  'set',
#  'chain',
#  'terrible',
#  'setting',
#  'pastries',
#  'nights',
#  'environment',
#  'ready',
#  'asian',
#  'ago',
#  'wings',
#  'afternoon',
#  'problem',
#  'reasonably',
#  'simply',
#  'past',
#  'entire',
#  'type',
#  'dr',
#  'cocktail',
#  'anywhere',
#  'deep',
#  'dark',
#  'beat',
#  'working',
#  'interior',
#  'tender',
#  'tap',
#  'seats',
#  'affordable',
#  'watching',
#  'soft',
#  'feeling',
#  'eaten',
#  'prefer',
#  'finally',
#  'potatoes',
#  'pancakes',
#  'called',
#  'blue',
#  'started',
#  'hands',
#  'middle',
#  'guy',
#  'particularly',
#  'noodle',
#  'diner',
#  'venue',
#  'surprisingly',
#  'quiet',
#  'gem',
#  '30',
#  'black',
#  'decided',
#  'crazy',
#  'bottle',
#  'tip',
#  'tour',
#  'low',
#  'doing',
#  'taking',
#  'forget',
#  'strong',
#  'meals',
#  'baked',
#  'recently',
#  'lobster',
#  'filling',
#  'mall',
#  'bartenders',
#  'together',
#  'guess',
#  'greasy',
#  'oysters',
#  'drive',
#  'thin',
#  'theater',
#  'easily',
#  'walked',
#  'soon',
#  'entrees',
#  'consistently',
#  'change',
#  'already',
#  'friday',
#  'believe',
#  'mac',
#  'fair',
#  'seriously',
#  'ribs',
#  'heard',
#  'dog',
#  'tuna',
#  'slice',
#  'generous',
#  'head',
#  'twice',
#  'taco',
#  'korean',
#  'level',
#  'gone',
#  'play',
#  'saw',
#  'number',
#  'within',
#  'mix',
#  'onion',
#  'visiting',
#  'stores',
#  'per',
#  'cost',
#  'comfort',
#  'unless',
#  'ended',
#  'vietnamese',
#  'club',
#  '12',
#  'center',
#  'pool',
#  'groups',
#  'certainly',
#  'unfortunately',
#  'school',
#  'rich',
#  'incredibly',
#  'despite',
#  'mostly',
#  'fruit',
#  'sausage',
#  'four',
#  'customers',
#  'sports',
#  'buffet',
#  'takes',
#  'corn',
#  'bars',
#  'appreciate',
#  'efficient',
#  'dumplings',
#  'arrived',
#  'true',
#  'oil',
#  'exactly',
#  'cut',
#  'serves',
#  'pot',
#  'upscale',
#  'meet',
#  'kinda',
#  'corner',
#  'spots',
#  'poor',
#  'museum',
#  'games',
#  'bought',
#  'offers',
#  'el',
#  'upstairs',
#  'hand',
#  'tomato',
#  'tapas',
#  'organic',
#  'los',
#  'chowder',
#  '8',
#  'original',
#  'mixed',
#  'goes',
#  'sea',
#  'event',
#  'serving',
#  'completely',
#  'rib',
#  'heart',
#  'behind',
#  'wide',
#  'deli',
#  'sales',
#  'mouth',
#  'veggies',
#  'sauces',
#  'plan',
#  'north',
#  'hidden',
#  'compared',
#  'meats',
#  'orange',
#  'bakery',
#  'salty',
#  'heavy',
#  'craving',
#  'company',
#  'sides',
#  'sat',
#  'filled',
#  'cookies',
#  'youve',
#  'difficult',
#  'combo',
#  'salt',
#  'mean',
#  'waited',
#  'ahead',
#  'bridge',
#  'somewhat',
#  'n',
#  'stand',
#  'pad',
#  'fabulous',
#  '7',
#  'tons',
#  'superb',
#  'sunny',
#  'generally',
#  'due',
#  'ambience',
#  'waiters',
#  'cakes',
#  'book',
#  'belly',
#  'usual',
#  'spectacular',
#  'glad',
#  'disappointing',
#  'wow',
#  'overrated',
#  'homemade',
#  'roasted',
#  'known',
#  'sort',
#  'apple',
#  'weve',
#  'hear',
#  'please',
#  'note',
#  'diego',
#  'delivery',
#  'smaller',
#  'chill',
#  'margaritas',
#  'famous',
#  'square',
#  'man',
#  'bike',
#  'youd',
#  'touch',
#  'satisfied',
#  'worst',
#  'mountain',
#  'charge',
#  'romantic',
#  'prime',
#  'consistent',
#  'juicy',
#  'exceptional',
#  'theyve']

# %%
#removing stop words
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/mgvasque/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
wordCount = defaultdict(int)
punctuation = set(string.punctuation)
for d in data:
    if type(d['reviewText']) == str:
        r = ''.join([c for c in d['reviewText'].lower() if not c in punctuation])
        for w in r.split():
            if w not in stop_words:
                wordCount[w] += 1

counts = [(wordCount[w], w) for w in wordCount]
counts.sort()
counts.reverse()

# %%
#EDA top words
counts[:10]
# Out:
# [(28827, 'food'),
#  (28762, 'good'),
#  (27991, 'great'),
#  (23042, 'place'),
#  (14069, 'service'),
#  (11499, 'like'),
#  (11397, 'get'),
#  (10658, 'best'),
#  (10246, 'one'),
#  (10117, 'really')]

# %%
#sentimental analysis

# %%
wordId = dict(zip(words, range(len(words))))
wordSet = set(words)

# %%
def feature(d):
    feat = [0]*len(words)
    if type(d['reviewText']) == str:
        r = ''.join([c for c in d['reviewText'].lower() if not c in punctuation])
        ws = r.split()
        ws2 = [' '.join(x) for x in list(zip(ws[:-1],ws[1:]))]
        ws3 = [' '.join(x) for x in list(zip(ws[:-2],ws[1:-1],ws[2:]))]
        ws4 = [' '.join(x) for x in list(zip(ws[:-3],ws[1:-2],ws[2:-1],ws[3:]))]
        ws5 = [' '.join(x) for x in list(zip(ws[:-4],ws[1:-3],ws[2:-2],ws[3:-1],ws[4:]))]
        for w in ws + ws2 + ws3 + ws4 + ws5:
            if w in words:
                feat[wordId[w]] += 1
    feat.append(1)
    return feat

# %%
X = [feature(d) for d in data[:60000]]
y = [d['rating'] for d in data[:60000]]

# %%
clf = linear_model.Ridge(1.0, fit_intercept=False)
clf.fit(X, y)
theta = clf.coef_
predictions = clf.predict(X)

# %%
predictions
# Out:
# array([4.41584228, 4.33374715, 3.92004417, ..., 4.22580846, 3.92381399,
#        3.97584104])
